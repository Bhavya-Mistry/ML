# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavya-Mistry/Data-Science/blob/main/p1(One_hot_encoding__more_precise).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("p1.xlsx")

# %%
df1.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df1['Date_of_Journey'] = pd.to_datetime(df1['Date_of_Journey'], format = '%d/%m/%Y')

df1['Day'] = df1['Date_of_Journey'].dt.day_name()

# %%
df1['Day'].unique()
# Out:
# array(['Sunday', 'Wednesday', 'Friday', 'Monday', 'Tuesday', 'Saturday',
#        'Thursday'], dtype=object)

# %%
df2 = df1

# print(df2.head())

def weekdayornot(x):
  if x == "Sunday" or x == "Saturday":
    return "Weekend"
  else :
    return "Weekday"

df2['weekdayornot'] = df2['Day'].apply(weekdayornot)

print(df2['weekdayornot'].unique())
# Out:
# ['Weekend' 'Weekday']

# %%
df2.drop("Date_of_Journey", inplace = True, axis =1)

# %%
df2.drop("Day", inplace=True, axis =1 )

# %%
df2.drop(['Arrival_Time', 'Dep_Time'], axis=1, inplace=True)

print(df2.head())
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price weekdayornot
# 0    non-stop         No info   3897      Weekend
# 1     2 stops         No info   7662      Weekday
# 2     2 stops         No info  13882      Weekend
# 3      1 stop         No info   6218      Weekend
# 4      1 stop         No info  13302      Weekday

# %%
df2.drop("Route" , inplace = True , axis = 1)

# %%
df2.head()
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m      1 stop         No info
#
#    Price weekdayornot
# 0   3897      Weekend
# 1   7662      Weekday
# 2  13882      Weekend
# 3   6218      Weekend
# 4  13302      Weekday

# %%
df2["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
print(df2.isnull().sum())

df2.dropna(inplace = True, axis = 0)
# Out:
# Airline            0
# Source             0
# Destination        0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# weekdayornot       0
# dtype: int64

# %%
def con_to_mins(z):
  hrs = 0
  mins = 0
  if 'h' in z:
    hrs = int(z.split('h')[0])
  if 'm' in z:
    mins = int(z.split('m')[0].split()[-1])
  return hrs * 60 + mins

# %%
df3 = df2

# %%
df3.head()
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m      1 stop         No info
#
#    Price weekdayornot
# 0   3897      Weekend
# 1   7662      Weekday
# 2  13882      Weekend
# 3   6218      Weekend
# 4  13302      Weekday

# %%
df3['Duration'] = df['Duration'].apply(con_to_mins)
df3.head()
# Out:
#        Airline    Source Destination  Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi       170    non-stop         No info
# 1    Air India   Kolkata    Banglore       445     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      1140     2 stops         No info
# 3       IndiGo   Kolkata    Banglore       325      1 stop         No info
# 4       IndiGo  Banglore   New Delhi       285      1 stop         No info
#
#    Price weekdayornot
# 0   3897      Weekend
# 1   7662      Weekday
# 2  13882      Weekend
# 3   6218      Weekend
# 4  13302      Weekday

# %%
df4 = pd.get_dummies(df3, columns=['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info', 'weekdayornot'], drop_first=True)

df4.head()
# Out:
#    Duration  Price  Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# 0       170   3897              False          False            True
# 1       445   7662               True          False           False
# 2      1140  13882              False          False           False
# 3       325   6218              False          False            True
# 4       285  13302              False          False            True
#
#    Airline_Jet Airways  Airline_Jet Airways Business  \
# 0                False                         False
# 1                False                         False
# 2                 True                         False
# 3                False                         False
# 4                False                         False
#
#    Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 0                      False                                      False
# 1                      False                                      False
# ...

# %%
df4.to_csv('onehot_encoded.csv', index=False)
from google.colab import files


# Download the file to your local PC
files.download('onehot_encoded.csv')

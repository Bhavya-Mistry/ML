# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavya-Mistry/Data-Science/blob/main/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("p1.xlsx")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
le = LabelEncoder()

# %%
df["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df["Airline_encoded"] = le.fit_transform(df["Airline"])
df.drop("Airline",axis=1, inplace=True)

# %%
df["Source_encoded"] = le.fit_transform(df["Source"])
df.drop("Source", axis=1, inplace=True)

# %%
df['Additional_Info_encoded'] = le.fit_transform(df["Additional_Info"])
df.drop("Additional_Info", inplace = True, axis=1)

# %%
df["Destination_encoded"] = le.fit_transform(df["Destination"])
df.drop("Destination", axis = 1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Date_of_Journey            0
# Route                      1
# Dep_Time                   0
# Arrival_Time               0
# Duration                   0
# Total_Stops                1
# Price                      0
# Airline_encoded            0
# Source_encoded             0
# Additional_Info_encoded    0
# Destination_encoded        0
# dtype: int64

# %%
print(df["Total_Stops"].unique())

df.dropna(inplace=True)

df.isnull().sum()
# Out:
# ['non-stop' '2 stops' '1 stop' '3 stops' nan '4 stops']
# Date_of_Journey            0
# Route                      0
# Dep_Time                   0
# Arrival_Time               0
# Duration                   0
# Total_Stops                0
# Price                      0
# Airline_encoded            0
# Source_encoded             0
# Additional_Info_encoded    0
# Destination_encoded        0
# dtype: int64

# %%
df["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['non-stop', '2 stops', '1 stop', '3 stops', '4 stops']])

df["Total_Stops_encoded"] = oe.fit_transform(df[["Total_Stops"]])
df.drop("Total_Stops", axis=1, inplace=True)

# %%
df.head()
# Out:
#   Date_of_Journey                  Route Dep_Time  Arrival_Time Duration  \
# 0      24/03/2019              BLR → DEL    22:20  01:10 22 Mar   2h 50m
# 1       1/05/2019  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m
# 2       9/06/2019  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h
# 3      12/05/2019        CCU → NAG → BLR    18:05         23:30   5h 25m
# 4      01/03/2019        BLR → NAG → DEL    16:50         21:35   4h 45m
#
#    Price  Airline_encoded  Source_encoded  Additional_Info_encoded  \
# 0   3897                3               0                        8
# 1   7662                1               3                        8
# 2  13882                4               2                        8
# 3   6218                3               3                        8
# 4  13302                3               0                        8
#
#    Destination_encoded  Total_Stops_encoded
# 0                    5                  0.0
# ...

# %%
df["Date_of_Journey"].unique()
# Out:
# array(['24/03/2019', '1/05/2019', '9/06/2019', '12/05/2019', '01/03/2019',
#        '24/06/2019', '12/03/2019', '27/05/2019', '1/06/2019',
#        '18/04/2019', '9/05/2019', '24/04/2019', '3/03/2019', '15/04/2019',
#        '12/06/2019', '6/03/2019', '21/03/2019', '3/04/2019', '6/05/2019',
#        '15/05/2019', '18/06/2019', '15/06/2019', '6/04/2019',
#        '18/05/2019', '27/06/2019', '21/05/2019', '06/03/2019',
#        '3/06/2019', '15/03/2019', '3/05/2019', '9/03/2019', '6/06/2019',
#        '24/05/2019', '09/03/2019', '1/04/2019', '21/04/2019',
#        '21/06/2019', '27/03/2019', '18/03/2019', '12/04/2019',
#        '9/04/2019', '1/03/2019', '03/03/2019', '27/04/2019'], dtype=object)

# %%
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'], format='%d/%m/%Y')

df.head()

df['Year'] = df['Date_of_Journey'].dt.year
df['Month'] = df['Date_of_Journey'].dt.month
df['Day'] = df['Date_of_Journey'].dt.day
df['DayOfWeek'] = df['Date_of_Journey'].dt.day_name()

df.drop("Date_of_Journey",axis=1,inplace=True)

df.head()
# Out:
#                    Route Dep_Time  Arrival_Time Duration  Price  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m   3897
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m   7662
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h  13882
# 3        CCU → NAG → BLR    18:05         23:30   5h 25m   6218
# 4        BLR → NAG → DEL    16:50         21:35   4h 45m  13302
#
#    Airline_encoded  Source_encoded  Additional_Info_encoded  \
# 0                3               0                        8
# 1                1               3                        8
# 2                4               2                        8
# 3                3               3                        8
# 4                3               0                        8
#
#    Destination_encoded  Total_Stops_encoded  Year  Month  Day  DayOfWeek
# 0                    5                  0.0  2019      3   24     Sunday
# ...

# %%
df["Dep_Time"].unique()
# Out:
# array(['22:20', '05:50', '09:25', '18:05', '16:50', '09:00', '18:55',
#        '08:00', '08:55', '11:25', '09:45', '20:20', '11:40', '21:10',
#        '17:15', '16:40', '08:45', '14:00', '20:15', '16:00', '14:10',
#        '22:00', '04:00', '21:25', '21:50', '07:00', '07:05', '09:50',
#        '14:35', '10:35', '15:05', '14:15', '06:45', '20:55', '11:10',
#        '05:45', '19:00', '23:05', '11:00', '09:35', '21:15', '23:55',
#        '19:45', '08:50', '15:40', '06:05', '15:00', '13:55', '05:55',
#        '13:20', '05:05', '06:25', '17:30', '08:20', '19:55', '06:30',
#        '14:05', '02:00', '09:40', '08:25', '20:25', '13:15', '02:15',
#        '16:55', '20:45', '05:15', '19:50', '20:00', '06:10', '19:30',
#        '04:45', '12:55', '18:15', '17:20', '15:25', '23:00', '12:00',
#        '14:45', '11:50', '11:30', '14:40', '19:10', '06:00', '23:30',
#        '07:35', '13:05', '12:30', '15:10', '12:50', '18:25', '16:30',
# ...

# %%
import pandas as pd


df['Dep_Time'] = pd.to_datetime(df['Dep_Time'], format='%H:%M')

df['Dep_Hour'] = df['Dep_Time'].dt.hour
df['Dep_Minute'] = df['Dep_Time'].dt.minute

df.drop("Dep_Time",axis=1,inplace=True)


df.head()
# Out:
#                    Route  Arrival_Time Duration  Price  Airline_encoded  \
# 0              BLR → DEL  01:10 22 Mar   2h 50m   3897                3
# 1  CCU → IXR → BBI → BLR         13:15   7h 25m   7662                1
# 2  DEL → LKO → BOM → COK  04:25 10 Jun      19h  13882                4
# 3        CCU → NAG → BLR         23:30   5h 25m   6218                3
# 4        BLR → NAG → DEL         21:35   4h 45m  13302                3
#
#    Source_encoded  Additional_Info_encoded  Destination_encoded  \
# 0               0                        8                    5
# 1               3                        8                    0
# 2               2                        8                    1
# 3               3                        8                    0
# 4               0                        8                    5
#
#    Total_Stops_encoded  Year  Month  Day  DayOfWeek  Dep_Hour  Dep_Minute
# ...

# %%
df.head()
# Out:
#                    Route  Arrival_Time Duration  Price  Airline_encoded  \
# 0              BLR → DEL  01:10 22 Mar   2h 50m   3897                3
# 1  CCU → IXR → BBI → BLR         13:15   7h 25m   7662                1
# 2  DEL → LKO → BOM → COK  04:25 10 Jun      19h  13882                4
# 3        CCU → NAG → BLR         23:30   5h 25m   6218                3
# 4        BLR → NAG → DEL         21:35   4h 45m  13302                3
#
#    Source_encoded  Additional_Info_encoded  Destination_encoded  \
# 0               0                        8                    5
# 1               3                        8                    0
# 2               2                        8                    1
# 3               3                        8                    0
# 4               0                        8                    5
#
#    Total_Stops_encoded  Year  Month  Day  DayOfWeek  Dep_Hour  Dep_Minute
# ...

# %%
def time(x):
  if 5 <= x < 12:
    return "Morning"
  elif 12 <= x <16:
    return "Afternoon"
  elif 16<= x <21:
    return "Evening"
  else:
    return "Night"

df["Dep_Day"] = df["Dep_Hour"].apply(time)

df.head()
# Out:
#                    Route  Arrival_Time Duration  Price  Airline_encoded  \
# 0              BLR → DEL  01:10 22 Mar   2h 50m   3897                3
# 1  CCU → IXR → BBI → BLR         13:15   7h 25m   7662                1
# 2  DEL → LKO → BOM → COK  04:25 10 Jun      19h  13882                4
# 3        CCU → NAG → BLR         23:30   5h 25m   6218                3
# 4        BLR → NAG → DEL         21:35   4h 45m  13302                3
#
#    Source_encoded  Additional_Info_encoded  Destination_encoded  \
# 0               0                        8                    5
# 1               3                        8                    0
# 2               2                        8                    1
# 3               3                        8                    0
# 4               0                        8                    5
#
#    Total_Stops_encoded  Year  Month  Day  DayOfWeek  Dep_Hour  Dep_Minute  \
# ...

# %%
# df.drop("Dep_Hour",inplace=True, axis = 1)
df.drop("Dep_Minute",inplace=True, axis = 1)

# %%
df.head()
# Out:
#                    Route  Arrival_Time Duration  Price  Airline_encoded  \
# 0              BLR → DEL  01:10 22 Mar   2h 50m   3897                3
# 1  CCU → IXR → BBI → BLR         13:15   7h 25m   7662                1
# 2  DEL → LKO → BOM → COK  04:25 10 Jun      19h  13882                4
# 3        CCU → NAG → BLR         23:30   5h 25m   6218                3
# 4        BLR → NAG → DEL         21:35   4h 45m  13302                3
#
#    Source_encoded  Additional_Info_encoded  Destination_encoded  \
# 0               0                        8                    5
# 1               3                        8                    0
# 2               2                        8                    1
# 3               3                        8                    0
# 4               0                        8                    5
#
#    Total_Stops_encoded  Year  Month  Day  DayOfWeek  Dep_Hour  Dep_Day
# 0                  0.0  2019      3   24     Sunday        22    Night
# ...

# %%
df["dep_day_encoded"] = le.fit_transform(df["Dep_Day"])

df.head()
# Out:
#                    Route  Arrival_Time Duration  Price  Airline_encoded  \
# 0              BLR → DEL  01:10 22 Mar   2h 50m   3897                3
# 1  CCU → IXR → BBI → BLR         13:15   7h 25m   7662                1
# 2  DEL → LKO → BOM → COK  04:25 10 Jun      19h  13882                4
# 3        CCU → NAG → BLR         23:30   5h 25m   6218                3
# 4        BLR → NAG → DEL         21:35   4h 45m  13302                3
#
#    Source_encoded  Additional_Info_encoded  Destination_encoded  \
# 0               0                        8                    5
# 1               3                        8                    0
# 2               2                        8                    1
# 3               3                        8                    0
# 4               0                        8                    5
#
#    Total_Stops_encoded  Year  Month  Day  DayOfWeek  Dep_Hour  Dep_Day  \
# 0                  0.0  2019      3   24     Sunday        22    Night
# ...

# %%
# df.drop("Dep_Day", inplace=True, axis = 1)
df.head()

# df["DayOfWeek_encoded"] = le.fit_transform(df["DayOfWeek"])
# df.drop("DayOfWeek", inplace=True, axis = 1)

df.head()
# Out:
#                    Route  Arrival_Time Duration  Price  Airline_encoded  \
# 0              BLR → DEL  01:10 22 Mar   2h 50m   3897                3
# 1  CCU → IXR → BBI → BLR         13:15   7h 25m   7662                1
# 2  DEL → LKO → BOM → COK  04:25 10 Jun      19h  13882                4
# 3        CCU → NAG → BLR         23:30   5h 25m   6218                3
# 4        BLR → NAG → DEL         21:35   4h 45m  13302                3
#
#    Source_encoded  Additional_Info_encoded  Destination_encoded  \
# 0               0                        8                    5
# 1               3                        8                    0
# 2               2                        8                    1
# 3               3                        8                    0
# 4               0                        8                    5
#
#    Total_Stops_encoded  Year  Month  Day  DayOfWeek  Dep_Hour  Dep_Day  \
# 0                  0.0  2019      3   24     Sunday        22    Night
# ...

# %%
df.drop("Arrival_Time",inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-17b11e2efb38> in <cell line: 1>()
# ----> 1 df.drop("Arrival_Time",inplace = True, axis = 1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df["DayOfWeek_encoded"] = le.fit_transform(df["DayOfWeek"])
df.drop("DayOfWeek",inplace = True , axis=1)
df.head()
# Out:
#                    Route Duration  Price  Airline_encoded  Source_encoded  \
# 0              BLR → DEL   2h 50m   3897                3               0
# 1  CCU → IXR → BBI → BLR   7h 25m   7662                1               3
# 2  DEL → LKO → BOM → COK      19h  13882                4               2
# 3        CCU → NAG → BLR   5h 25m   6218                3               3
# 4        BLR → NAG → DEL   4h 45m  13302                3               0
#
#    Additional_Info_encoded  Destination_encoded  Total_Stops_encoded  Year  \
# 0                        8                    5                  0.0  2019
# 1                        8                    0                  1.0  2019
# 2                        8                    1                  1.0  2019
# 3                        8                    0                  2.0  2019
# 4                        8                    5                  2.0  2019
#
#    Month  Day  Dep_Hour  Dep_Day  dep_day_encoded  DayOfWeek_encoded
# ...

# %%
df["Dep_Day_encoded"] = le.fit_transform(df["Dep_Day"])
df.drop("Dep_Day",inplace = True, axis = 1)

# %%
df.head()
# Out:
#                    Route Duration  Price  Airline_encoded  Source_encoded  \
# 0              BLR → DEL   2h 50m   3897                3               0
# 1  CCU → IXR → BBI → BLR   7h 25m   7662                1               3
# 2  DEL → LKO → BOM → COK      19h  13882                4               2
# 3        CCU → NAG → BLR   5h 25m   6218                3               3
# 4        BLR → NAG → DEL   4h 45m  13302                3               0
#
#    Additional_Info_encoded  Destination_encoded  Total_Stops_encoded  Year  \
# 0                        8                    5                  0.0  2019
# 1                        8                    0                  1.0  2019
# 2                        8                    1                  1.0  2019
# 3                        8                    0                  2.0  2019
# 4                        8                    5                  2.0  2019
#
# ...

# %%
df.dtypes
# Out:
# Route                       object
# Duration                    object
# Price                        int64
# Airline_encoded              int64
# Source_encoded               int64
# Additional_Info_encoded      int64
# Destination_encoded          int64
# Total_Stops_encoded        float64
# Year                         int32
# Month                        int32
# Day                          int32
# Dep_Hour                     int32
# dep_day_encoded              int64
# DayOfWeek_encoded            int64
# Dep_Day_encoded              int64
# dtype: object

# %%
df.drop("Year", inplace = True , axis = 1)

# %%
def convert_to_minutes(duration):
    hours = 0
    minutes = 0
    if 'h' in duration:
        hours = int(duration.split('h')[0])
    if 'm' in duration:
        minutes = int(duration.split('m')[0].split()[-1])
    return hours * 60 + minutes

# Apply the function to the 'Duration' column
df['Duration_Minutes'] = df['Duration'].apply(convert_to_minutes)

# Display the resulting DataFrame
df.head()
# Out:
#                    Route Duration  Price  Airline_encoded  Source_encoded  \
# 0              BLR → DEL   2h 50m   3897                3               0
# 1  CCU → IXR → BBI → BLR   7h 25m   7662                1               3
# 2  DEL → LKO → BOM → COK      19h  13882                4               2
# 3        CCU → NAG → BLR   5h 25m   6218                3               3
# 4        BLR → NAG → DEL   4h 45m  13302                3               0
#
#    Additional_Info_encoded  Destination_encoded  Total_Stops_encoded  Month  \
# 0                        8                    5                  0.0      3
# 1                        8                    0                  1.0      5
# 2                        8                    1                  1.0      6
# 3                        8                    0                  2.0      5
# 4                        8                    5                  2.0      3
#
# ...

# %%
df.drop("Duration", inplace = True, axis = 1)

# %%
df.head()
# Out:
#                    Route  Price  Airline_encoded  Source_encoded  \
# 0              BLR → DEL   3897                3               0
# 1  CCU → IXR → BBI → BLR   7662                1               3
# 2  DEL → LKO → BOM → COK  13882                4               2
# 3        CCU → NAG → BLR   6218                3               3
# 4        BLR → NAG → DEL  13302                3               0
#
#    Additional_Info_encoded  Destination_encoded  Total_Stops_encoded  Month  \
# 0                        8                    5                  0.0      3
# 1                        8                    0                  1.0      5
# 2                        8                    1                  1.0      6
# 3                        8                    0                  2.0      5
# 4                        8                    5                  2.0      3
#
#    Day  Dep_Hour  dep_day_encoded  DayOfWeek_encoded  Dep_Day_encoded  \
# ...

# %%
df['route_length'] = df['Route'].str.count('→') + 1

# Find the maximum route length (i.e., the maximum number of cities in any route)
max_route_length = df['route_length'].max()

# %%
print(max_route_length)
# Out:
# 6

# %%
df.head()
# Out:
#                    Route  Price  Airline_encoded  Source_encoded  \
# 0              BLR → DEL   3897                3               0
# 1  CCU → IXR → BBI → BLR   7662                1               3
# 2  DEL → LKO → BOM → COK  13882                4               2
# 3        CCU → NAG → BLR   6218                3               3
# 4        BLR → NAG → DEL  13302                3               0
#
#    Additional_Info_encoded  Destination_encoded  Total_Stops_encoded  Month  \
# 0                        8                    5                  0.0      3
# 1                        8                    0                  1.0      5
# 2                        8                    1                  1.0      6
# 3                        8                    0                  2.0      5
# 4                        8                    5                  2.0      3
#
#    Day  Dep_Hour  dep_day_encoded  DayOfWeek_encoded  Dep_Day_encoded  \
# ...

# %%
import pandas as pd

# Set the maximum number of rows to display
pd.set_option('display.max_rows', None)

# Now display the value counts
print(df["Route"].value_counts())
# Out:
# Route
# DEL → BOM → COK                      2376
# BLR → DEL                            1552
# CCU → BOM → BLR                       979
# CCU → BLR                             724
# BOM → HYD                             621
# CCU → DEL → BLR                       565
# BLR → BOM → DEL                       402
# MAA → CCU                             381
# DEL → HYD → COK                       326
# DEL → JAI → BOM → COK                 240
# DEL → BLR → COK                       232
# DEL → COK                             213
# DEL → AMD → BOM → COK                 205
# DEL → MAA → COK                       146
# DEL → IDR → BOM → COK                  99
# DEL → HYD → MAA → COK                  83
# DEL → NAG → BOM → COK                  71
# CCU → MAA → BLR                        65
# DEL → GOI → BOM → COK                  58
# DEL → HYD → BOM → COK                  56
# CCU → HYD → BLR                        53
# CCU → BBI → BLR                        50
# ...

# %%
df["Route1"] = df["Route"].str.split('→').str[0]
df["Route2"] = df["Route"].str.split('→').str[1]
df["Route3"] = df["Route"].str.split('→').str[2]
df["Route4"] = df["Route"].str.split('→').str[3]
df["Route5"] = df["Route"].str.split('→').str[4]
df["Route6"] = df["Route"].str.split('→').str[5]

# %%
df.head()
# df.drop("Route6]",inplace = True, axis =1)
df.drop("Route]",inplace = True, axis =1)
# df.drop("Route6]",inplace = True, axis =1)
# df.drop("Route6]",inplace = True, axis =1)

# %%
df.fillna("NONE", inplace = True)

# %%
df.head()
# Out:
#                    Route  Price  Airline_encoded  Source_encoded  \
# 0              BLR → DEL   3897                3               0
# 1  CCU → IXR → BBI → BLR   7662                1               3
# 2  DEL → LKO → BOM → COK  13882                4               2
# 3        CCU → NAG → BLR   6218                3               3
# 4        BLR → NAG → DEL  13302                3               0
#
#    Additional_Info_encoded  Destination_encoded  Total_Stops_encoded  Month  \
# 0                        8                    5                  0.0      3
# 1                        8                    0                  1.0      5
# 2                        8                    1                  1.0      6
# 3                        8                    0                  2.0      5
# 4                        8                    5                  2.0      3
#
#    Day  Dep_Hour  ...  Route3  Route4  Route5  Route1_encoded  Route6  \
# ...

# %%
df["Route1_encoded"] = le.fit_transform(df["Route1"])
df["Route2_encoded"] = le.fit_transform(df["Route2"])
df["Route3_encoded"] = le.fit_transform(df["Route3"])
df["Route4_encoded"] = le.fit_transform(df["Route4"])
df["Route5_encoded"] = le.fit_transform(df["Route5"])
df["Route6_encoded"] = le.fit_transform(df["Route6"])

# %%
df.drop("Route", inplace = True, axis = 1)
df.drop("Route1", inplace = True, axis = 1)
df.drop("Route2", inplace = True, axis = 1)
df.drop("Route3", inplace = True, axis = 1)
df.drop("Route4", inplace = True, axis = 1)
df.drop("Route5", inplace = True, axis = 1)
df.drop("Route6", inplace = True, axis = 1)
df.drop("route_length", inplace = True , axis = 1)

# %%
df.head()
# Out:
#    Price  Airline_encoded  Source_encoded  Additional_Info_encoded  \
# 0   3897                3               0                        8
# 1   7662                1               3                        8
# 2  13882                4               2                        8
# 3   6218                3               3                        8
# 4  13302                3               0                        8
#
#    Destination_encoded  Total_Stops_encoded  Month  Day  Dep_Hour  \
# 0                    5                  0.0      3   24        22
# 1                    0                  1.0      5    1         5
# 2                    1                  1.0      6    9         9
# 3                    0                  2.0      5   12        18
# 4                    5                  2.0      3    1        16
#
#    dep_day_encoded  DayOfWeek_encoded  Dep_Day_encoded  Duration_Minutes  \
# 0                3                  3                3               170
# ...

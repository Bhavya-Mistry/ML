# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavya-Mistry/Linear-Regression/blob/main/LR_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Salary_Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
# X = df["YearsExperience"].values
X = df.iloc[:,0:1].values
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
Y = df.iloc[:,1:].values
Y
# Out:
# array([[ 39343],
#        [ 46205],
#        [ 37731],
#        [ 43525],
#        [ 39891],
#        [ 56642],
#        [ 60150],
#        [ 54445],
#        [ 64445],
#        [ 57189],
#        [ 63218],
#        [ 55794],
#        [ 56957],
#        [ 57081],
#        [ 61111],
#        [ 67938],
#        [ 66029],
#        [ 83088],
#        [ 81363],
#        [ 93940],
#        [ 91738],
#        [ 98273],
#        [101302],
#        [113812],
#        [109431],
#        [105582],
#        [116969],
#        [112635],
#        [122391],
#        [121872]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
plt.plot(X,Y, color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=23)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y)
plt.plot(X, lr.predict(X), color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Fit Line")
plt.show()

# %%
pred_y = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y_test, pred_y)
print("Accuracy: ",r2*100)
# Out:
# Accuracy:  91.84170849214232

# %%
#testing it with random numers:
lr.predict([[100]])
# Out:
# array([[955297.58389699]])
